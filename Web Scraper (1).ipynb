# %%
from bs4 import BeautifulSoup
import requests
import time
import datetime

import smtplib
import numpy as np
import pandas as pd

# %%
url = "https://www.ambitionbox.com/list-of-companies?hiring=true&sort_by=toprated"
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36"}
    
page = requests.get(url, headers = headers).text

 
soup1 = BeautifulSoup(page,'lxml')


companies = soup1.find_all("div", class_= "company-content")


        
name=[]
rating=[]
review=[]
ctype=[]
location=[]
age=[]
totemp=[]

for i in companies:
    
    name.append(i.find("h2").text.strip())
    rating.append(i.find("p", class_="rating").text.strip())
    review.append(i.find("a", class_="review-count").text.strip())
   
    #ctype.append(i.find_all("p", class_="infoEntity sbold-list-header")(0).text.strip())
    #location.append(i.find_all("p", class_="infoEntity sbold-list-header")(1).text.strip())
    #age.append(i.find_all("p", class_="infoEntity sbold-list-header")(2).text.strip())
    #totemp.append(i.find_all("p", class_="infoEntity sbold-list-header")(3).text.strip())
   

    


        
 #'ctype':ctype, 'location':location, 'age':age, 'totemp':totemp}       


d = {'name': name, 'rating':rating, 'review':review } 

df=pd.DataFrame(d)


df
# Out:
#                      name rating         review
# 0        Glorious Insight    5.0  (412 Reviews)
# 1               Appsierra    5.0  (197 Reviews)
# 2       ScoreMe Solutions    5.0   (90 Reviews)
# 3               Brainvire    4.9  (290 Reviews)
# 4                  Aurigo    4.9  (191 Reviews)
# 5                 Fingent    4.9  (143 Reviews)
# 6   Grass Roots Resear...    4.9   (96 Reviews)
# 7         Resurgent India    4.9  (138 Reviews)
# 8            BEO Software    4.9  (130 Reviews)
# 9        Ducima Analytics    5.0   (57 Reviews)
# 10             CodeClouds    4.8  (196 Reviews)
# 11          Fipola Retail    4.9   (82 Reviews)
# 12        Wintax Solution    4.9   (67 Reviews)
# 13     Hirva HR Solutions    5.0   (49 Reviews)
# 14                 6Sense    5.0   (44 Reviews)
# 15                 BYGRAD    5.0   (34 Reviews)
# 16           Skilliantech    4.8  (143 Reviews)
# 17       Crescendo Global    4.8   (88 Reviews)
# 18                   ETOE    5.0   (30 Reviews)
# ...

# %%
i.find("a", class_="review-count").text.strip()
# Out:
# '(412 Reviews)'

# %%
for j in soupy : 
    print (j.text.strip ())
    
    
soupy2= soup1.find_all ("p", class_="rating")
for i in soupy2:
    print (i.text.strip ())
    
    
name []
rating []
review []

# %%
print (len(companies))
# Out:
# 30
